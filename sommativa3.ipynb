# %% [markdown]
# <a href="https://colab.research.google.com/github/BernasconiLorenzo06/PANDAS_FILE/blob/main/sommativa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('https://github.com/PolisenoRiccardo/perilPopolo/blob/main/milano_housing_02_2_23.xlsx?raw=true')
df
# Out:
#       index rooms     m2 bathrooms floor condominium_expenses        date  \
# 0         0     3  140.0         2     4                  535  08/02/2023
# 1         0     4  121.0         2     3                  200  17/02/2023
# 2         0     2   55.0         1     4                  133  20/02/2023
# 3         0     2   60.0         1     5                  333  11/01/2023
# 4         0     4  220.0         3     4                  NaN  23/01/2023
# ...     ...   ...    ...       ...   ...                  ...         ...
# 2125      0     2   70.0         1    10                  135  26/02/2023
# 2126      0     3   90.0         2     R                  183  19/02/2023
# 2127      0     3  130.0         2     T                  200  26/02/2023
# 2128      0     2   51.0         1     1                  NaN  26/02/2023
# 2129      0     2   72.0         1   NaN                  250  26/02/2023
#
#      contract                                           typology total_floors  \
# 0        sale  apartment | entire property | stately property...     6 floors
# 1        sale  apartment | entire property | stately property...     7 floors
# 2        sale   attic | entire property | stately property class     4 floors
# 3        sale     attic | bare ownership | medium property class     5 floors
# 4        sale  apartment | entire property | stately property...     7 floors
# ...       ...                                                ...          ...
# 2125     sale  apartment | entire property | stately property...    11 floors
# 2126     sale  apartment | entire property | medium property ...     7 floors
# 2127     sale  apartment | entire property | stately property...     4 floors
# 2128     sale  apartment | entire property | stately property...     5 floors
# 2129     sale  apartment | entire property | medium property ...     5 floors
#
#       ... energy_certification co2_emissions  elevator  floor_level  \
# 0     ...                  NaN           NaN         1            4
# 1     ...                  NaN           NaN         1            3
# 2     ...                  NaN           NaN         1            4
# 3     ...                  NaN           NaN         1            5
# 4     ...                  NaN           NaN         1            4
# ...   ...                  ...           ...       ...          ...
# 2125  ...                  NaN           NaN         1            1
# 2126  ...                  NaN           NaN         1            0
# 2127  ...                  NaN           NaN         0            0
# 2128  ...                  NaN           NaN         1            1
# 2129  ...                  NaN           NaN         1            2
#
#      heating_centralized heating_radiator           heating_gas  \
# 0            centralized     to radiators       methane powered
# 1             autonomous     to radiators           gas powered
# 2             autonomous     to radiators           gas powered
# 3            centralized     to radiators       methane powered
# 4            centralized     to radiators       methane powered
# ...                  ...              ...                   ...
# 2125         centralized           by air       methane powered
# 2126         centralized     to radiators       methane powered
# 2127          autonomous           by air  powered by heat pump
# 2128          autonomous     to radiators           gas powered
# 2129         centralized     to radiators                   NaN
#
#      air_conditiong_centralized air_conditioning_heat  \
# 0                    autonomous              cold/hot
# 1            system preparation                   NaN
# 2                    autonomous              cold/hot
# 3                    autonomous                  cold
# 4                    autonomous              cold/hot
# ...                         ...                   ...
# 2125                 autonomous              cold/hot
# 2126                 autonomous                  cold
# 2127                 autonomous              cold/hot
# 2128         system preparation                   NaN
# 2129         system preparation                   NaN
#
#      renewable_energy_performance_index_KWh/m2
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                        351.0
# ...                                        ...
# 2125                                       NaN
# 2126                                       NaN
# 2127                                       NaN
# 2128                                       NaN
# 2129                                       NaN
#
# [2130 rows x 34 columns]

# %% [markdown]
# 1. avere l'elenco degli appartamenti in vendita in un certo quartiere inserito dall'utente. Visualizzare gli appartamenti in ordine di data

# %%
quartiere = input("inserire un quartiere")
df[df["neighborhood"] == quartiere]
# Out:
# inserire un quartiereaffori
#       index  rooms     m2 bathrooms floor condominium_expenses        date  \
# 43        0      4  130.0         1     5                  300  23/02/2023
# 54        0      2   75.0         1     R                  167  06/02/2023
# 116       0      4  120.0         2     2                  250  14/02/2023
# 219       0  2 - 5   81.0        11   NaN                  NaN  10/01/2023
# 469       0      4  118.0         1     6                  240  21/02/2023
# 532       0      2   46.0         1     S                  125  10/01/2023
# 607       0      2   65.0         1     1                  110  22/02/2023
# 638       0  2 - 4   69.0         5   NaN                  NaN  18/01/2023
# 697       0      2   45.0         1     2                   70  11/02/2023
# 1083      0      1   70.0         1     S                  NaN  21/11/2022
# 1161      0      4  134.0         2   NaN                  100  19/01/2023
# 1168      0      3  103.0         1   NaN                  100  19/01/2023
# 1255      0     5+  313.0        3+     T                  100  11/02/2023
# 1463      0      2   64.0         1     T                  NaN  23/02/2023
# 1521      0      2   70.0         1     7                  216  16/02/2023
# 1546      0      4  120.0         2     3                  250  24/02/2023
# 1550      0      2   55.0         1     6                  133  24/02/2023
# 1551      0      2   65.0         1     R                  108  24/02/2023
# 1560      0      2   65.0         1     T                   72  23/01/2023
# 1852      0      2   75.0         1     T                  NaN  24/02/2023
#
#                             contract  \
# 43                              sale
# 54                              sale
# 116                             sale
# 219   sale - download specifications
# 469                             sale
# 532                             sale
# 607                             sale
# 638                             sale
# 697                             sale
# 1083                            sale
# 1161                            sale
# 1168                            sale
# 1255                            sale
# 1463                            sale
# 1521                            sale
# 1546                            sale
# 1550                            sale
# 1551                            sale
# 1560                            sale
# 1852                            sale
#
#                                                typology total_floors  ...  \
# 43     attic | entire property | stately property class     5 floors  ...
# 54    apartment | entire property | medium property ...     2 floors  ...
# 116   apartment | entire property | stately property...     7 floors  ...
# 219                                             project     8 floors  ...
# 469   apartment | entire property | medium property ...     9 floors  ...
# 532   apartment | entire property | stately property...      1 floor  ...
# 607    lofts | entire property | stately property class      1 floor  ...
# 638                           project | entire property          NaN  ...
# 697   apartment | entire property | medium property ...     3 floors  ...
# 1083    lofts | entire property | medium property class     6 floors  ...
# 1161  apartment | entire property | stately property...     5 floors  ...
# 1168  apartment | entire property | stately property...     5 floors  ...
# 1255  apartment | entire property | medium property ...      1 floor  ...
# 1463  apartment | entire property | medium property ...      1 floor  ...
# 1521  apartment | entire property | medium property ...     7 floors  ...
# 1546  apartment | entire property | medium property ...     4 floors  ...
# 1550  apartment | entire property | medium property ...     8 floors  ...
# 1551  apartment | entire property | economic propert...     6 floors  ...
# 1560  apartment | entire property | medium property ...     3 floors  ...
# 1852  apartment | entire property | medium property ...      1 floor  ...
#
#              energy_certification co2_emissions  elevator  floor_level  \
# 43                            NaN           NaN         1            5
# 54                            NaN           NaN         1            0
# 116                           NaN           NaN         1            2
# 219                           NaN           NaN         0          NaN
# 469                           NaN           NaN         1            6
# 532                           NaN           NaN         0            S
# 607                           NaN           NaN         0            1
# 638                           NaN           NaN         0          NaN
# 697                           NaN           NaN         0            2
# 1083                          NaN           NaN         0            S
# 1161                          NaN           NaN         1            2
# 1168                          NaN           NaN         1            2
# 1255                          NaN           NaN         0            0
# 1463  In attesa di certificazione           NaN         0            0
# 1521                          NaN           NaN         1            7
# 1546                          NaN           NaN         1            3
# 1550                          NaN           NaN         1            6
# 1551                          NaN           NaN         1            0
# 1560                          NaN           NaN         0            0
# 1852                          NaN           NaN         0            0
#
#      heating_centralized heating_radiator           heating_gas  \
# 43           centralized     to radiators           gas powered
# 54           centralized     to radiators       methane powered
# 116          centralized     to radiators           gas powered
# 219          centralized     On the floor  powered by heat pump
# 469          centralized     to radiators       methane powered
# 532          centralized     to radiators       methane powered
# 607           autonomous     to radiators           gas powered
# 638                  NaN              NaN                   NaN
# 697           autonomous     to radiators       methane powered
# 1083         centralized     to radiators       methane powered
# 1161          autonomous     On the floor                   NaN
# 1168          autonomous     On the floor                   NaN
# 1255          autonomous     to radiators       methane powered
# 1463          autonomous     On the floor  powered by heat pump
# 1521         centralized     to radiators       methane powered
# 1546         centralized     to radiators       methane powered
# 1550         centralized     to radiators       methane powered
# 1551         centralized     to radiators       methane powered
# 1560          autonomous     to radiators       methane powered
# 1852          autonomous     to radiators       methane powered
#
#      air_conditiong_centralized air_conditioning_heat  \
# 43                   autonomous                  cold
# 54                   autonomous              cold/hot
# 116                  autonomous              cold/hot
# 219                 centralized                  cold
# 469                         NaN                   NaN
# 532                  autonomous              cold/hot
# 607                  autonomous              cold/hot
# 638                         NaN                   NaN
# 697                         NaN                   NaN
# 1083                        NaN                   NaN
# 1161         system preparation                   NaN
# 1168         system preparation                   NaN
# 1255                 autonomous              cold/hot
# 1463                 autonomous              cold/hot
# 1521                 autonomous              cold/hot
# 1546                 autonomous                  cold
# 1550                        NaN                   NaN
# 1551                 autonomous                  cold
# 1560                 autonomous              cold/hot
# 1852                 autonomous                  cold
#
#      renewable_energy_performance_index_KWh/m2
# 43                                         NaN
# 54                                         NaN
# 116                                        NaN
# 219                                        NaN
# 469                                        NaN
# 532                                        NaN
# 607                                        NaN
# 638                                        NaN
# 697                                        NaN
# 1083                                       NaN
# 1161                                       NaN
# 1168                                       NaN
# 1255                                       NaN
# 1463                                       NaN
# 1521                                       NaN
# 1546                                       NaN
# 1550                                       NaN
# 1551                                       NaN
# 1560                                       NaN
# 1852                                       NaN
#
# [20 rows x 34 columns]

# %% [markdown]
# 2. avere l'elenco dei quartieri presenti nel dataset. Visualizzare l'elenco in ordine alfabetico senza ripetizioni (estrarre tutti i quartieri e poi usare i metodi delle liste/tuple/insiemi/dizionari per eliminare i doppioni)

# %%
dfquartieri = df[["neighborhood"]].sort_values(by="neighborhood")
a=set(df['neighborhood'])
a
# Out:
# {'affori',
#  'amendola - buonarroti',
#  'arco della pace',
#  'arena',
#  'argonne - corsica',
#  'ascanio sforza',
#  'baggio',
#  'bande nere',
#  'barona',
#  'bicocca',
#  'bignami - ponale',
#  'bisceglie',
#  'bocconi',
#  'bologna - sulmona',
#  'borgogna - largo augusto',
#  'bovisa',
#  'bovisasca',
#  'brera',
#  'bruzzano',
#  'buenos aires',
#  "ca' granda",
#  'cadore',
#  'cadorna - castello',
#  'cantalupa - san paolo',
#  'carrobbio',
#  'cascina dei pomi',
#  'cascina merlata - musocco',
#  'casoretto',
#  'cenisio',
#  'centrale',
#  'cermenate - abbiategrasso',
#  'certosa',
#  'chiesa rossa',
#  'cimiano',
#  'città studi',
#  'city life',
#  'comasina',
#  'corso genova',
#  'corso san gottardo',
#  'corvetto',
#  'crescenzago',
#  'de angeli',
#  'dergano',
#  'dezza',
#  'duomo',
#  'famagosta',
#  'farini',
#  'figino',
#  'frua',
#  'gallaratese',
#  'gambara',
#  'garibaldi - corso como',
#  'ghisolfa - mac mahon',
#  'giambellino',
#  'gorla',
#  'gratosoglio',
#  'greco - segnano',
#  'guastalla',
#  'indipendenza',
#  'inganni',
#  'isola',
#  'istria',
#  'lambrate',
#  'lanza',
#  'lodi - brenta',
#  'lorenteggio',
#  'maggiolina',
#  'martini - insubria',
#  'melchiorre gioia',
#  'missori',
#  'molise - cuoco',
#  'monte rosa - lotto',
#  'monte stella',
#  'montenero',
#  'morgagni',
#  'moscova',
#  'muggiano',
#  nan,
#  'navigli - darsena',
#  'niguarda',
#  'ortica',
#  'pagano',
#  'palestro',
#  'paolo sarpi',
#  'parco lambro',
#  'parco trotter',
#  'pasteur',
#  'pezzotti - meda',
#  'piave - tricolore',
#  'piazza napoli',
#  'piazzale siena',
#  'plebisciti - susa',
#  'ponte lambro',
#  'ponte nuovo',
#  'porta nuova',
#  "porta romana - medaglie d'oro",
#  'porta venezia',
#  'porta vittoria',
#  'portello - parco vittoria',
#  'prato centenaro',
#  'precotto',
#  'primaticcio',
#  'qt8',
#  'quadrilatero della moda',
#  'quadronno - crocetta',
#  'quartiere adriano',
#  'quartiere feltre',
#  'quartiere forlanini',
#  'quartiere olmi',
#  'quarto cagnino',
#  'quarto oggiaro',
#  'quinto romano',
#  'quintosole - chiaravalle',
#  'repubblica',
#  'ripamonti',
#  'rogoredo',
#  'roserio',
#  'rovereto',
#  'rubattino',
#  'san babila',
#  'san carlo',
#  'san siro',
#  'san vittore',
#  "sant'ambrogio",
#  'santa giulia',
#  'scala - manzoni',
#  'sempione',
#  'solari',
#  'ticinese',
#  'tre castelli - faenza',
#  'trenno',
#  'tripoli - soderini',
#  'turati',
#  'turro',
#  'udine',
#  'vercelli - wagner',
#  'via dei ciclamini 11',
#  'via giuseppina lazzaroni',
#  'via valsesia',
#  'vialba',
#  'viale ungheria - mecenate',
#  'vigentino - fatima',
#  'villa san giovanni',
#  'vincenzo monti',
#  'washington',
#  'zara'}

# %% [markdown]
# 3. avere l'elenco dei quartieri presenti nel dataset. Visualizzare l'elenco in ordine alfabetico senza ripetizioni (usare i metodi di pandas per eliminare i doppioni)

# %%
dfquartieri = df[["neighborhood"]].sort_values(by="neighborhood")
result = dfquartieri.drop_duplicates()
result
# Out:
#                neighborhood
# 1852                 affori
# 326   amendola - buonarroti
# 946         arco della pace
# 99                    arena
# 1809      argonne - corsica
# ...                     ...
# 203      villa san giovanni
# 266          vincenzo monti
# 1825             washington
# 723                    zara
# 259                     NaN
#
# [146 rows x 1 columns]

# %% [markdown]
# 4. visualizzare il prezzo medio di una zona di Milano inserita dall'utente

# %%
quartiere = input("inserire un quartiere")
dfmedio = df[df["neighborhood"] == quartiere][["price"]].mean()
dfmedio
# Out:
# inserire un quartiereaffori
# price    309444.444444
# dtype: float64

# %% [markdown]
# 5. visualizzare il prezzo medio di ogni quartiere di Milano. Ordinare i risultati in ordine decrescente sul prezzo medio

# %%
dfmedie = df.groupby("neighborhood")[["price"]].mean()
dfmedie
# Out:
#                               price
# neighborhood
# affori                 3.094444e+05
# amendola - buonarroti  7.701250e+05
# arco della pace        1.553636e+06
# arena                  8.477273e+05
# argonne - corsica      5.341905e+05
# ...                             ...
# vigentino - fatima     3.419000e+05
# villa san giovanni     3.858571e+05
# vincenzo monti         1.556623e+06
# washington             7.999000e+05
# zara                   8.167000e+05
#
# [145 rows x 1 columns]

# %% [markdown]
# 6. scrivere una funzione che converta un prezzo in euro in un'altra valuta. La funzione ha due parametri: il prezzo in euro e il tasso di conversione euro-altra valuta. Utilizzare questa funzione per modificare l'esercizio 5 facendo inserire all'utente il tasso di conversione e visualizzando i risultati nella nuova valuta.

# %%
def converti_valuta(prezzo_euro, tasso_conversione):
    prezzo_altra_valuta = prezzo_euro * tasso_conversione
    return prezzo_altra_valuta


tasso = float(input("Inserisci il tasso di conversione: "))
prezzo_altra_valuta = converti_valuta(dfmedie, tasso)
print("Il prezzo convertito è:", prezzo_altra_valuta)
